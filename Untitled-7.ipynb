# %%
import pandas as pd
import openpyxl

agosto2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Agosto 2014")
agosto2014
septiembre2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Septiembre 2014")
septiembre2014
octubre2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Octubre 2014")
octubre2014

trimestre2014=pd.concat([agosto2014,septiembre2014,octubre2014])
trimestre2014

print(len(trimestre2014.columns))
# Out:
# 9

# %%
import pandas as pd
import openpyxl
agosto2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Agosto 2014")
agosto2014
septiembre2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Septiembre 2014")
septiembre2014
octubre2014=pd.read_excel(r"C:\temp\VentasGroucery_Meses.xlsx",sheet_name="Ventas Octubre 2014")
octubre2014

trimestre2014=pd.concat([agosto2014,septiembre2014,octubre2014])
trimestre2014
# Out:
#     Order ID                          Product        Category  Unit Price  \
# 0      10248    Singaporean Hokkien Fried Mee  Grains/Cereals         9.8
# 1      10248           Mozzarella di Giovanni  Dairy Products        34.8
# 2      10248                   Queso Cabrales  Dairy Products        14.0
# 3      10249                             Tofu         Produce        18.6
# 4      10249            Manjimup Dried Apples         Produce        42.4
# ..       ...                              ...             ...         ...
# 52     10315                    Sasquatch Ale       Beverages        11.2
# 53     10315                    Outback Lager       Beverages        12.0
# 54     10316  Jack's New England Clam Chowder         Seafood         7.7
# 55     10316                   Tarte au sucre     Confections        39.4
# 56     10317                             Chai       Beverages        14.4
#
#     Quantity                    Customer    Ship City Ship Country Order Date
# ...

# %%
str=[trimestre2014.Category.unique()]
str.replace("/"," ")
[trimestre2014.Category.unique()].count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 str=[trimestre2014.Category.unique()]
# ----> 2 str.replace("/"," ")
#       3 [trimestre2014.Category.unique()].count
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
str="Grains/Cereals"
str.replace("/"," ")
# Out:
# 'Grains Cereals'
